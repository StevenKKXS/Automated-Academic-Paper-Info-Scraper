# %%
import os
from os import path as op
import time

import requests
from bs4 import BeautifulSoup
import pandas as pd

# selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

def get_request(url):
    while True:
        try:
            response = requests.get(url)
            if response.status_code == 404:
                return None
            response.raise_for_status()  # 如果响应状态不是200，引发HTTPError异常
            return response.text
        except requests.exceptions.RequestException as err:
            print(f"Network error occurred: {err}. Retrying...")
            time.sleep(1)  # Wait for 1 seconds before retrying

def get_authors(li):
    spans = li.find('cite').find_all('span', attrs={'itemprop': 'author'})
    authors = [span.text for span in spans]
    return ', '.join(authors)

def get_paper_title(li):
    title = li.find('span', attrs={'itemprop': 'name', 'class' : 'title'}).text
    if title[-1] == '.':
        title = title[:-1]
    return title

def get_journal_conf_dblp_abbr(li):
    return li['id'].split('/')[1]

def get_year(li):
    return li.find('span', attrs={'itemprop': 'datePublished'}).text

# text excluding children's text
def get_text_excluding_children(driver, element):
    return driver.execute_script("""
    return jQuery(arguments[0]).contents().filter(function() {
        return this.nodeType == Node.TEXT_NODE;
    }).text();
    """, element)

# EI
def get_ei_result(title, k=5, time_limit=60):
    title = title.strip()
    ev_url = 'https://www.engineeringvillage.com/search/quick.url' # Engineering Village search url
    # set options
    options = webdriver.EdgeOptions()
    # useragent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0'
    useragent = ''
    options.add_argument("user-agent:{}".format(useragent))
    options.add_argument('--headless')

    # webdriver
    driver = webdriver.Edge(options = options)
    driver.get(ev_url)

    # wait at most time_limit sec
    wait_t = 0
    waiting = True
    while waiting:
        try:
            search_box = driver.find_element(By.ID, "search-word-1")
            waiting = False
        except:
            if wait_t > time_limit-1:
                return None
            time.sleep(1)
            wait_t += 1
    time.sleep(1)
    # typing and searching simulation
    search_box.send_keys(title)
    search_box.send_keys(Keys.ENTER)

    # search result
    wait_t = 0
    waiting = True
    while waiting:
        try:
            search_list = driver.find_element(By.ID, "result_0")
            waiting = False
        except:
            if wait_t > time_limit-1:
                return None
            time.sleep(1)
            wait_t += 1
    time.sleep(1)
    search_titles = search_list.find_elements(By.XPATH, '//h3[@class="result-title"]')[:k]
    
    # check if the first k related search result is the input title
    # return is_ei
    is_ei = False
    for search_title in search_titles:
        doc_type = search_title.find_element(By.XPATH, '//div[@class="row db-doctype-info"]').find_element(By.TAG_NAME, 'div')
        if get_text_excluding_children(driver, doc_type).strip() == 'Preprint (PP)':
            # skip the PrePrint paper
            continue
        search_t_ele = search_titles[0].find_element(By.TAG_NAME, 'a')
        search_t = get_text_excluding_children(driver, search_t_ele).strip()
        if search_t == title:
            is_ei = True
            break
    driver.close()
    return is_ei

# SCI
def get_sci_result(title, k=5, time_limit=60):
    wos_base_url = 'https://www.webofscience.com'
    wos_searh_url = 'https://www.webofscience.com/wos/alldb/basic-search' 
	# set options
    options = webdriver.EdgeOptions()
    # useragent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0'
    useragent = ''
    options.add_argument("user-agent:{}".format(useragent))
    options.add_argument('--headless')


    # webdriver
    driver = webdriver.Edge(options = options)
    # navigate to search page
    driver.get(wos_searh_url)

    # wait at most time_limit sec
    wait_t = 0
    waiting = True
    while waiting:
        try:
            accept_cookies_btn = driver.find_element(By.XPATH, '//button[@id="onetrust-accept-btn-handler"]')
            search_box = driver.find_element(By.ID, "mat-input-0")
            search_btn = driver.find_element(By.XPATH, '//button[@data-ta="run-search"]')
            waiting = False
        except:
            if wait_t > time_limit-1:
                return None
            time.sleep(1)
            wait_t += 1
    time.sleep(1)
    accept_cookies_btn.click() # accept cookies (if do not do so, the search button will be intercepted)
    search_box.send_keys(title) # send title to search box
    search_btn.click() # click search
    
    # if url is not change : return False (no result in wos)
    time.sleep(1)
    if driver.current_url == 'https://webofscience.clarivate.cn/wos/alldb/basic-search':
        driver.close()
        return False

    driver.implicitly_wait(time_limit)
    close_tips = driver.find_element(By.XPATH, '//button[@aria-label="Close" and @id="pendo-close-guide-30f847dd"]')
    close_tips.click()

    # wait at most time_limit sec
    wait_t = 0
    waiting = True
    while waiting:
        try:         
            search_list = driver.find_elements(By.XPATH, '//a[@data-ta="summary-record-title-link"]')
            waiting = False
        except Exception as e:
            #print(e)
            #print('wait {}'.format(wait_t))
            if wait_t > time_limit-1:
                return None
            time.sleep(1)
            wait_t += 1
    time.sleep(1)

    # check if the first k related search result is the input title
    # return is_sci
    is_sci = False
    candidates = search_list[:k]
    for cand in candidates:
        if cand.text.strip() == title:
            is_sci = True
            break
  
    driver.close()
    return is_sci

# %%
urls_dblp = [
    'https://dblp.uni-trier.de/pid/59/1007.html', # hxn
    'https://dblp.uni-trier.de/pid/31/2864-10.html', # wx
    'https://dblp.uni-trier.de/pid/183/9198.html', # ffl
    'https://dblp.uni-trier.de/pid/63/1591-8.html', # ws
    'https://dblp.uni-trier.de/pid/96/1538.html', # hyb
    'https://dblp.uni-trier.de/pid/257/4945.html', # wjc
]
hxn_html = get_request('https://dblp.uni-trier.de/pid/59/1007.html')
soup = BeautifulSoup(hxn_html, 'html.parser')

# %%
'''paper_list_cell = soup.find_all('ul', attrs={'class': 'publ-list'})[0]
paper_list = []
for li in paper_list_cell.children:
    if len(li['class'])<=1 and li['class'][0] == 'year':
        if li.text == '2023':
            continue
        elif li.text != '2023':
            break
    if li['class'][1] == 'informal':
        continue
    print(li['class'])
    paper_list.append(li)'''
journal_paper_list = []
journal_paper_title_set = set()
conference_paper_list = []
conference_paper_title_set = set()
for url in urls_dblp:
    dblp_html = get_request(url)
    soup = BeautifulSoup(dblp_html, 'html.parser')
    paper_list_cell = soup.find_all('ul', attrs={'class': 'publ-list'})[0]
    for li in paper_list_cell.children:
        if len(li['class'])<=1 and li['class'][0] == 'year':
            if li.text == '2023':
                continue
            elif li.text != '2023':
                break
        if li['class'][1] == 'informal':
            continue
        elif li['class'][1] == 'article':
            title = get_paper_title(li)
            if title in journal_paper_title_set:
                continue
            journal_paper_title_set.add(title)
            journal_paper_list.append(li)
        elif li['class'][1] == 'inproceedings':
            title = get_paper_title(li)
            if title in conference_paper_title_set:
                continue
            conference_paper_title_set.add(title)
            conference_paper_list.append(li)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\WorkSpace\Vscode\Projects\Miscellany\DBLPScraping\DBLPScraping.ipynb Cell 3 line 1
#      <a href='vscode-notebook-cell:/c%3A/WorkSpace/Vscode/Projects/Miscellany/DBLPScraping/DBLPScraping.ipynb#W2sZmlsZQ%3D%3D?line=16'>17</a> for url in urls_dblp:
#      <a href='vscode-notebook-cell:/c%3A/WorkSpace/Vscode/Projects/Miscellany/DBLPScraping/DBLPScraping.ipynb#W2sZmlsZQ%3D%3D?line=17'>18</a>     dblp_html = get_request(url)
# ---> <a href='vscode-notebook-cell:/c%3A/WorkSpace/Vscode/Projects/Miscellany/DBLPScraping/DBLPScraping.ipynb#W2sZmlsZQ%3D%3D?line=18'>19</a>     soup = BeautifulSoup(dblp_html, 'html.parser')
#      <a href='vscode-notebook-cell:/c%3A/WorkSpace/Vscode/Projects/Miscellany/DBLPScraping/DBLPScraping.ipynb#W2sZmlsZQ%3D%3D?line=19'>20</a>     paper_list_cell = soup.find_all('ul', attrs={'class': 'publ-list'})[0]
#      <a href='vscode-notebook-cell:/c%3A/WorkSpace/Vscode/Projects/Miscellany/DBLPScraping/DBLPScraping.ipynb#W2sZmlsZQ%3D%3D?line=20'>21</a>     for li in paper_list_cell.children:
#
# File c:\Users\StevenKKXS\anaconda3\envs\spiderman\Lib\site-packages\bs4\__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File c:\Users\StevenKKXS\anaconda3\envs\spiderman\Lib\site-packages\bs4\__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File c:\Users\StevenKKXS\anaconda3\envs\spiderman\Lib\site-packages\bs4\builder\_htmlparser.py:380, in HTMLParserTreeBuilder.feed(self, markup)
#     378 parser.soup = self.soup
#     379 try:
# --> 380     parser.feed(markup)
#     381 except AssertionError as e:
#     382     # html.parser raises AssertionError in rare cases to
#     383     # indicate a fatal problem with the markup, especially
#     384     # when there's an error in the doctype declaration.
#     385     raise ParserRejectedMarkup(e)
#
# File c:\Users\StevenKKXS\anaconda3\envs\spiderman\Lib\html\parser.py:110, in HTMLParser.feed(self, data)
#     104 r"""Feed data to the parser.
#     105
#     106 Call this as often as you want, with as little or as much text
#     107 as you want (may include '\n').
#     108 """
#     109 self.rawdata = self.rawdata + data
# --> 110 self.goahead(0)
#
# File c:\Users\StevenKKXS\anaconda3\envs\spiderman\Lib\html\parser.py:172, in HTMLParser.goahead(self, end)
#     170     k = self.parse_starttag(i)
#     171 elif startswith("</", i):
# --> 172     k = self.parse_endtag(i)
#     173 elif startswith("<!--", i):
#     174     k = self.parse_comment(i)
#
# File c:\Users\StevenKKXS\anaconda3\envs\spiderman\Lib\html\parser.py:384, in HTMLParser.parse_endtag(self, i)
#     382 if not match:
#     383     return -1
# --> 384 gtpos = match.end()
#     385 match = endtagfind.match(rawdata, i) # </ + tag + >
#     386 if not match:
#
# KeyboardInterrupt:

# %%
paper_infos = []
for paper in journal_paper_list + conference_paper_list:
    aus = get_authors(paper)
    title = get_paper_title(paper)
    year = get_year(paper)
    abbr = get_journal_conf_dblp_abbr(paper)
    pub_type = 'journal' if paper['class'][1] == 'article' else 'conference'
    info = {
        'authors': aus,
        'title': title,
        'year': year,
        'abbr': abbr,
        'type': pub_type
    }
    paper_infos.append(info)

print(len(paper_infos))
# Out:
# 74

# %%
conf_abbrs = set()
jour_abbrs = set()
for p_info in paper_infos:
    if p_info['type'] == 'journal':
        jour_abbrs.add(p_info['abbr'])
    else:
        conf_abbrs.add(p_info['abbr'])
print(conf_abbrs)
print(jour_abbrs)
# Out:
# {'icde', 'aaai', 'www', 'kdd', 'iclr', 'recsys', 'ijcai', 'sigir', 'cikm', 'cvpr', 'mm', 'wsdm', 'icse', 'acl', 'kddcd'}
# {'pami', 'tkde', 'prl', 'tcss', 'tmm', 'tsmc', 'ijautcomp', 'tois', 'fcsc', 'tomccap'}

# %%
for p_info in paper_infos:
    title = p_info['title']
    if p_info.get('ei') is not None and p_info.get('sci') is not None:
        print(p_info)
        continue
    try:
        is_ei = get_ei_result(title, time_limit=30)
        is_sci = get_sci_result(title, time_limit=30)
        p_info.update({'ei': is_ei, 'sci': is_sci})
    except Exception as e:
        with open('running_exception.log' , 'a', encoding='utf-8') as f:
            print('-'*100, file=f)
            print('Error occurred with paper : {}'.format(p_info['title']), file=f)
            # print(e, file=f)
    print(p_info)
# Out:
# {'authors': 'Yuan Gao, Xiang Wang, Xiangnan He, Huamin Feng, Yong-Dong Zhang', 'title': 'Rumor detection with self-supervised learning on texts and social graph', 'year': '2023', 'abbr': 'fcsc', 'type': 'journal', 'ei': True, 'sci': True}
# {'authors': 'Xiang Wang, Yingxin Wu, An Zhang, Fuli Feng, Xiangnan He, Tat-Seng Chua', 'title': 'Reinforced Causal Explainer for Graph Neural Networks', 'year': '2023', 'abbr': 'pami', 'type': 'journal', 'ei': True, 'sci': True}
# {'authors': 'Kang Liu, Feng Xue, Xiangnan He, Dan Guo, Richang Hong', 'title': 'Joint Multi-Grained Popularity-Aware Graph Convolution Collaborative Filtering for Recommendation', 'year': '2023', 'abbr': 'tcss', 'type': 'journal', 'ei': True, 'sci': False}
# {'authors': 'Jintang Li, Tao Xie, Liang Chen, Fenfang Xie, Xiangnan He, Zibin Zheng', 'title': 'Adversarial Attack on Large Scale Graph', 'year': '2023', 'abbr': 'tkde', 'type': 'journal', 'ei': True, 'sci': False}
# {'authors': 'Fuli Feng, Xiangnan He, Hanwang Zhang, Tat-Seng Chua', 'title': 'Cross-GCN: Enhancing Graph Convolutional Network with $k$k-Order Feature Interactions', 'year': '2023', 'abbr': 'tkde', 'type': 'journal', 'ei': False, 'sci': False}
# {'authors': 'Yu Zheng, Chen Gao, Xiangnan He, Depeng Jin, Yong Li', 'title': 'Incorporating Price into Recommendation With Graph Convolutional Networks', 'year': '2023', 'abbr': 'tkde', 'type': 'journal', 'ei': False, 'sci': True}
# {'authors': 'Jianxin Chang, Chen Gao, Xiangnan He, Depeng Jin, Yong Li', 'title': 'Bundle Recommendation and Generation With Graph Neural Networks', 'year': '2023', 'abbr': 'tkde', 'type': 'journal', 'ei': True, 'sci': True}
# {'authors': 'Lei Chen, Fajie Yuan, Jiaxi Yang, Xiangnan He, Chengming Li, Min Yang', 'title': 'User-Specific Adaptive Fine-Tuning for Cross-Domain Recommendations', 'year': '2023', 'abbr': 'tkde', 'type': 'journal', 'ei': True, 'sci': True}
# {'authors': 'Weijian Chen, Fuli Feng, Qifan Wang, Xiangnan He, Chonggang Song, Guohui Ling, Yongdong Zhang', 'title': 'CatGCN: Graph Convolutional Networks With Categorical Node Features', 'year': '2023', 'abbr': 'tkde', 'type': 'journal', 'ei': True, 'sci': True}
# {'authors': 'Le Wu, Xiangnan He, Xiang Wang, Kun Zhang, Meng Wang', 'title': 'A Survey on Accuracy-Oriented Neural Recommendation: From Collaborative Filtering to Information-Rich Recommendation', 'year': '2023', 'abbr': 'tkde', 'type': 'journal', 'ei': True, 'sci': True}
# {'authors': 'Jiajia Chen, Xin Xin, Xianfeng Liang, Xiangnan He, Jun Liu', 'title': 'GDSRec: Graph-Based Decentralized Collaborative Filtering for Social Recommendation', 'year': '2023', 'abbr': 'tkde', 'type': 'journal', 'ei': True, 'sci': True}
# {'authors': 'Zihao Zhao, Jiawei Chen, Sheng Zhou, Xiangnan He, Xuezhi Cao, Fuzheng Zhang, Wei Wu', 'title': 'Popularity Bias is not Always Evil: Disentangling Benign and Harmful Bias for Recommendation', 'year': '2023', 'abbr': 'tkde', 'type': 'journal', 'ei': False, 'sci': False}
# {'authors': 'Yuyue Zhao, Xiang Wang, Jiawei Chen, Yashen Wang, Wei Tang, Xiangnan He, Haiyong Xie', 'title': 'Time-aware Path Reasoning on Knowledge Graph for Recommendation', 'year': '2023', 'abbr': 'tois', 'type': 'journal', 'ei': True, 'sci': True}
# {'authors': 'Xiangnan He, Yang Zhang, Fuli Feng, Chonggang Song, Lingling Yi, Guohui Ling, Yongdong Zhang', 'title': 'Addressing Confounding Feature Issue for Causal Recommendation', 'year': '2023', 'abbr': 'tois', 'type': 'journal', 'ei': True, 'sci': True}
# {'authors': 'Jiawei Chen, Hande Dong, Xiang Wang, Fuli Feng, Meng Wang, Xiangnan He', 'title': 'Bias and Debias in Recommender System: A Survey and Future Directions', 'year': '2023', 'abbr': 'tois', 'type': 'journal', 'ei': True, 'sci': False}
# {'authors': 'Honglei Zhang, Fangyuan Luo, Jun Wu, Xiangnan He, Yidong Li', 'title': 'LightFR: Lightweight Federated Recommendation with Privacy-preserving Matrix Factorization', 'year': '2023', 'abbr': 'tois', 'type': 'journal', 'ei': True, 'sci': True}
# {'authors': 'Shuo Wang, Huixia Ben, Yanbin Hao, Xiangnan He, Meng Wang', 'title': 'Boosting Hyperspectral Image Classification with Dual Hierarchical Learning', 'year': '2023', 'abbr': 'tomccap', 'type': 'journal', 'ei': True, 'sci': True}
# {'authors': 'Bin Wu, Xiangnan He, Le Wu, Xue Zhang, Yangdong Ye', 'title': 'Graph-Augmented Co-Attention Model for Socio-Sequential Recommendation', 'year': '2023', 'abbr': 'tsmc', 'type': 'journal', 'ei': True, 'sci': True}
# {'authors': 'Yinwei Wei, Xiang Wang, Liqiang Nie, Shaoyu Li, Dingxian Wang, Tat-Seng Chua', 'title': 'Causal Inference for Knowledge Graph Based Recommendation', 'year': '2023', 'abbr': 'tkde', 'type': 'journal', 'ei': True, 'sci': True}
# {'authors': 'Zhulin Tao, Xiaohao Liu, Yewei Xia, Xiang Wang, Lifang Yang, Xianglin Huang, Tat-Seng Chua', 'title': 'Self-Supervised Learning for Multimedia Recommendation', 'year': '2023', 'abbr': 'tmm', 'type': 'journal', 'ei': False, 'sci': False}
# {'authors': 'Hongyu Lu, Weizhi Ma, Yifan Wang, Min Zhang, Xiang Wang, Yiqun Liu, Tat-Seng Chua, Shaoping Ma', 'title': 'User Perception of Recommendation Explanation: Are Your Explanations What Users Need?', 'year': '2023', 'abbr': 'tois', 'type': 'journal', 'ei': None, 'sci': False}
# {'authors': 'Xin-Yu Lin, Yiyan Xu, Wenjie Wang, Yang Zhang, Fuli Feng', 'title': 'Mitigating Spurious Correlations for Self-supervised Recommendation', 'year': '2023', 'abbr': 'ijautcomp', 'type': 'journal', 'ei': True, 'sci': True}
# {'authors': 'Shengyu Zhang, Fuli Feng, Kun Kuang, Wenqiao Zhang, Zhou Zhao, Hongxia Yang, Tat-Seng Chua, Fei Wu', 'title': 'Personalized Latent Structure Learning for Recommendation', 'year': '2023', 'abbr': 'pami', 'type': 'journal', 'ei': True, 'sci': True}
# {'authors': 'Jinmeng Wu, Fulin Ge, Hanyu Hong, Yu Shi, Yanbin Hao, Lei Ma', 'title': 'Question-aware dynamic scene graph of local semantic representation learning for visual question answering', 'year': '2023', 'abbr': 'prl', 'type': 'journal', 'ei': True, 'sci': True}
# {'authors': 'Changyi Xiao, Xiangnan He, Yixin Cao', 'title': 'Knowledge Graph Embedding by Normalizing Flows', 'year': '2023', 'abbr': 'aaai', 'type': 'conference', 'ei': True, 'sci': False}
# {'authors': 'Xun Deng, Wenjie Wang, Fuli Feng, Hanwang Zhang, Xiangnan He, Yong Liao', 'title': 'Counterfactual Active Learning for Out-of-Distribution Generalization', 'year': '2023', 'abbr': 'acl', 'type': 'conference', 'ei': True, 'sci': False}
# {'authors': 'Wenjie Wang, Yong Liu, Yang Zhang, Weiwen Liu, Fuli Feng, Xiangnan He, Aixin Sun', 'title': 'The 1st Workshop on Recommendation with Generative Models', 'year': '2023', 'abbr': 'cikm', 'type': 'conference', 'ei': False, 'sci': False}
# {'authors': 'Zhicai Wang, Yanbin Hao, Tingting Mu, Ouxiang Li, Shuo Wang, Xiangnan He', 'title': 'Bi-Directional Distribution Alignment for Transductive Zero-Shot Learning', 'year': '2023', 'abbr': 'cvpr', 'type': 'conference', 'ei': True, 'sci': True}
# {'authors': 'Meng Jiang, Yang Zhang, Yuan Gao, Yansong Wang, Fuli Feng, Xiangnan He', 'title': 'LightMIRM: Light Meta-learned Invariant Risk Minimization for Trustworthy Loan Default Prediction', 'year': '2023', 'abbr': 'icde', 'type': 'conference', 'ei': True, 'sci': True}
# {'authors': 'Yang Liu, Liang Chen, Xiangnan He, Jiaying Peng, Zibin Zheng, Jie Tang', 'title': 'Modelling High-Order Social Relations for Item Recommendation (Extended Abstract)', 'year': '2023', 'abbr': 'icde', 'type': 'conference', 'ei': None, 'sci': True}
# {'authors': 'Bin Wu, Xiangnan He, Yu Chen, Liqiang Nie, Kai Zheng, Yangdong Ye', 'title': "Modeling Product's Visual and Functional Characteristics for Recommender Systems (Extended Abstract)", 'year': '2023', 'abbr': 'icde', 'type': 'conference', 'ei': None, 'sci': True}
# {'authors': 'Hang Pan, Jiawei Chen, Fuli Feng, Wentao Shi, Junkang Wu, Xiangnan He', 'title': 'Discriminative-Invariant Representation Learning for Unbiased Recommendation', 'year': '2023', 'abbr': 'ijcai', 'type': 'conference', 'ei': True, 'sci': False}
# {'authors': 'Jiarui Yu, Haoran Li, Yanbin Hao, Bin Zhu, Tong Xu, Xiangnan He', 'title': 'CgT-GAN: CLIP-guided Text GAN for Image Captioning', 'year': '2023', 'abbr': 'mm', 'type': 'conference', 'ei': False, 'sci': False}
# {'authors': 'Changsheng Wang, Jianbai Ye, Wenjie Wang, Chongming Gao, Fuli Feng, Xiangnan He', 'title': 'RecAD: Towards A Unified Library for Recommender Attack and Defense', 'year': '2023', 'abbr': 'recsys', 'type': 'conference', 'ei': True, 'sci': False}
# {'authors': 'Haoxuan Li, Taojun Hu, Zetong Xiong, Chunyuan Zheng, Fuli Feng, Xiangnan He, Xiao-Hua Zhou', 'title': 'ADRNet: A Generalized Collaborative Filtering Framework Combining Clinical and Non-Clinical Data for Adverse Drug Reaction Prediction', 'year': '2023', 'abbr': 'recsys', 'type': 'conference', 'ei': False, 'sci': False}
# {'authors': 'Jizhi Zhang, Keqin Bao, Yang Zhang, Wenjie Wang, Fuli Feng, Xiangnan He', 'title': 'Is ChatGPT Fair for Recommendation? Evaluating Fairness in Large Language Model Recommendation', 'year': '2023', 'abbr': 'recsys', 'type': 'conference', 'ei': False, 'sci': False}
# {'authors': 'Keqin Bao, Jizhi Zhang, Yang Zhang, Wenjie Wang, Fuli Feng, Xiangnan He', 'title': 'TALLRec: An Effective and Efficient Tuning Framework to Align Large Language Model with Recommendation', 'year': '2023', 'abbr': 'recsys', 'type': 'conference', 'ei': True, 'sci': False}
# {'authors': 'Chongming Gao, Kexin Huang, Jiawei Chen, Yuan Zhang, Biao Li, Peng Jiang, Shiqi Wang, Zhong Zhang, Xiangnan He', 'title': 'Alleviating Matthew Effect of Offline Reinforcement Learning in Interactive Recommendation', 'year': '2023', 'abbr': 'sigir', 'type': 'conference', 'ei': False, 'sci': True}
# {'authors': 'Zhengyi Yang, Xiangnan He, Jizhi Zhang, Jiancan Wu, Xin Xin, Jiawei Chen, Xiang Wang', 'title': 'A Generic Learning Framework for Sequential Recommendation with Distribution Shifts', 'year': '2023', 'abbr': 'sigir', 'type': 'conference', 'ei': True, 'sci': False}
# {'authors': 'Wenjie Wang, Yiyan Xu, Fuli Feng, Xinyu Lin, Xiangnan He, Tat-Seng Chua', 'title': 'Diffusion Recommender Model', 'year': '2023', 'abbr': 'sigir', 'type': 'conference', 'ei': True, 'sci': False}
# {'authors': 'Yang Zhang, Tianhao Shi, Fuli Feng, Wenjie Wang, Dingxian Wang, Xiangnan He, Yongdong Zhang', 'title': 'Reformulating CTR Prediction: Learning Invariant Feature Interactions for Recommendation', 'year': '2023', 'abbr': 'sigir', 'type': 'conference', 'ei': False, 'sci': False}
# {'authors': 'Wenjie Wang, Yang Zhang, Haoxuan Li, Peng Wu, Fuli Feng, Xiangnan He', 'title': 'Causal Recommendation: Progresses and Future Directions', 'year': '2023', 'abbr': 'sigir', 'type': 'conference', 'ei': True, 'sci': False}
# {'authors': 'Yuan Gao, Xiang Wang, Xiangnan He, Zhenguang Liu, Huamin Feng, Yongdong Zhang', 'title': 'Alleviating Structural Distribution Shift in Graph Anomaly Detection', 'year': '2023', 'abbr': 'wsdm', 'type': 'conference', 'ei': True, 'sci': True}
# {'authors': 'Junfeng Fang, Xiang Wang, An Zhang, Zemin Liu, Xiangnan He, Tat-Seng Chua', 'title': 'Cooperative Explanations of Graph Neural Networks', 'year': '2023', 'abbr': 'wsdm', 'type': 'conference', 'ei': True, 'sci': False}
# {'authors': 'Gang Chen, Jiawei Chen, Fuli Feng, Sheng Zhou, Xiangnan He', 'title': 'Unbiased Knowledge Distillation for Recommendation', 'year': '2023', 'abbr': 'wsdm', 'type': 'conference', 'ei': True, 'sci': False}
# {'authors': 'Jiancan Wu, Yi Yang, Yuchun Qian, Yongduo Sui, Xiang Wang, Xiangnan He', 'title': 'GIF: A General Graph Unlearning Strategy via Influence Function', 'year': '2023', 'abbr': 'www', 'type': 'conference', 'ei': False, 'sci': True}
# {'authors': 'Wentao Shi, Jiawei Chen, Fuli Feng, Jizhi Zhang, Junkang Wu, Chongming Gao, Xiangnan He', 'title': 'On the Theories Behind Hard Negative Sampling for Recommendation', 'year': '2023', 'abbr': 'www', 'type': 'conference', 'ei': True, 'sci': True}
# {'authors': 'Jiawei Chen, Junkang Wu, Jiancan Wu, Xuezhi Cao, Sheng Zhou, Xiangnan He', 'title': 'Adap-τ : Adaptively Modulating Embedding Magnitude for Recommendation', 'year': '2023', 'abbr': 'www', 'type': 'conference', 'ei': True, 'sci': False}
# {'authors': 'Yuan Gao, Xiang Wang, Xiangnan He, Zhenguang Liu, Huamin Feng, Yongdong Zhang', 'title': 'Addressing Heterophily in Graph Anomaly Detection: A Perspective of Graph Spectrum', 'year': '2023', 'abbr': 'www', 'type': 'conference', 'ei': True, 'sci': True}
# {'authors': 'An Zhang, Fangfu Liu, Wenchang Ma, Zhibo Cai, Xiang Wang, Tat-Seng Chua', 'title': 'Boosting Causal Discovery via Adaptive Sample Reweighting', 'year': '2023', 'abbr': 'iclr', 'type': 'conference', 'ei': False, 'sci': False}
# {'authors': 'Jiahao Liu, Jun Zeng, Xiang Wang, Zhenkai Liang', 'title': 'Learning Graph-based Code Representations for Source-level Functional Similarity Detection', 'year': '2023', 'abbr': 'icse', 'type': 'conference', 'ei': True, 'sci': True}
# {'authors': 'Fangfu Liu, Wenchang Ma, An Zhang, Xiang Wang, Yueqi Duan, Tat-Seng Chua', 'title': 'Discovering Dynamic Causal Space for DAG Structure Learning', 'year': '2023', 'abbr': 'kdd', 'type': 'conference', 'ei': True, 'sci': True}
# {'authors': 'Yunshan Ma, Chenchen Ye, Zijian Wu, Xiang Wang, Yixin Cao, Tat-Seng Chua', 'title': 'Context-aware Event Forecasting via Graph Disentanglement', 'year': '2023', 'abbr': 'kdd', 'type': 'conference', 'ei': False, 'sci': False}
# {'authors': 'Yicong Li, Xun Yang, An Zhang, Chun Feng, Xiang Wang, Tat-Seng Chua', 'title': 'Redundancy-aware Transformer for Video Question Answering', 'year': '2023', 'abbr': 'mm', 'type': 'conference', 'ei': False, 'sci': False}
# {'authors': 'Yinwei Wei, Xiaohao Liu, Yunshan Ma, Xiang Wang, Liqiang Nie, Tat-Seng Chua', 'title': 'Strategy-aware Bundle Recommender System', 'year': '2023', 'abbr': 'sigir', 'type': 'conference', 'ei': True, 'sci': True}
# {'authors': 'Yinwei Wei, Wenqi Liu, Fan Liu, Xiang Wang, Liqiang Nie, Tat-Seng Chua', 'title': 'LightGT: A Light Graph Transformer for Multimedia Recommendation', 'year': '2023', 'abbr': 'sigir', 'type': 'conference', 'ei': True, 'sci': True}
# {'authors': 'An Zhang, Jingnan Zheng, Xiang Wang, Yancheng Yuan, Tat-Seng Chua', 'title': 'Invariant Collaborative Filtering to Popularity Distribution Shift', 'year': '2023', 'abbr': 'www', 'type': 'conference', 'ei': False, 'sci': True}
# {'authors': 'Daizong Ding, Mi Zhang, Fuli Feng, Yuanmin Huang, Erling Jiang, Min Yang', 'title': 'Black-Box Adversarial Attack on Time Series Classification', 'year': '2023', 'abbr': 'aaai', 'type': 'conference', 'ei': True, 'sci': False}
# {'authors': 'Shengyu Zhang, Xusheng Feng, Wenyan Fan, Wenjing Fang, Fuli Feng, Wei Ji, Shuo Li, Li Wang, Shanshan Zhao, Zhou Zhao, Tat-Seng Chua, Fei Wu', 'title': 'Video-Audio Domain Generalization via Confounder Disentanglement', 'year': '2023', 'abbr': 'aaai', 'type': 'conference', 'ei': False, 'sci': False}
# {'authors': 'Moxin Li, Wenjie Wang, Fuli Feng, Hanwang Zhang, Qifan Wang, Tat-Seng Chua', 'title': 'Hypothetical Training for Robust Machine Reading Comprehension of Tabular Context', 'year': '2023', 'abbr': 'acl', 'type': 'conference', 'ei': True, 'sci': False}
# {'authors': 'Qifan Wang, Jingang Wang, Xiaojun Quan, Fuli Feng, Zenglin Xu, Shaoliang Nie, Sinong Wang, Madian Khabsa, Hamed Firooz, Dongfang Liu', 'title': 'MUSTIE: Multimodal Structural Transformer for Web Information Extraction', 'year': '2023', 'abbr': 'acl', 'type': 'conference', 'ei': True, 'sci': False}
# {'authors': 'Li Yang, Qifan Wang, Jingang Wang, Xiaojun Quan, Fuli Feng, Yu Chen, Madian Khabsa, Sinong Wang, Zenglin Xu, Dongfang Liu', 'title': 'MixPAVE: Mix-Prompt Tuning for Few-shot Product Attribute Value Extraction', 'year': '2023', 'abbr': 'acl', 'type': 'conference', 'ei': True, 'sci': False}
# {'authors': 'Yang Zhang, Yimeng Bai, Jianxin Chang, Xiaoxue Zang, Song Lu, Jing Lu, Fuli Feng, Yanan Niu, Yang Song', 'title': 'Leveraging Watch-time Feedback for Short-Video Recommendations: A Causal Labeling Framework', 'year': '2023', 'abbr': 'cikm', 'type': 'conference', 'ei': False, 'sci': False}
# {'authors': 'Yang Liu, Xiang Ao, Fuli Feng, Yunshan Ma, Kuan Li, Tat-Seng Chua, Qing He', 'title': 'FLOOD: A Flexible Invariant Learning Framework for Out-of-Distribution Generalization on Graphs', 'year': '2023', 'abbr': 'kdd', 'type': 'conference', 'ei': True, 'sci': False}
# {'authors': 'Shengyu Zhang, Yunze Tong, Kun Kuang, Fuli Feng, Jiezhong Qiu, Jin Yu, Zhou Zhao, Hongxia Yang, Zhongfei Zhang, Fei Wu', 'title': 'Stable Prediction on Graphs with Agnostic Distribution Shifts', 'year': '2023', 'abbr': 'kddcd', 'type': 'conference', 'ei': True, 'sci': False}
# {'authors': 'Wenjie Wang, Xinyu Lin, Liuhui Wang, Fuli Feng, Yinwei Wei, Tat-Seng Chua', 'title': 'Equivariant Learning for Out-of-Distribution Cold-start Recommendation', 'year': '2023', 'abbr': 'mm', 'type': 'conference', 'ei': None, 'sci': True}
# {'authors': 'Wei Ji, Renjie Liang, Lizi Liao, Hao Fei, Fuli Feng', 'title': 'Partial Annotation-based Video Moment Retrieval via Iterative Learning', 'year': '2023', 'abbr': 'mm', 'type': 'conference', 'ei': None, 'sci': False}
# {'authors': 'Yulong Huang, Yang Zhang, Qifan Wang, Chenxu Wang, Fuli Feng', 'title': 'Prediction then Correction: An Abductive Prediction Correction Method for Sequential Recommendation', 'year': '2023', 'abbr': 'sigir', 'type': 'conference', 'ei': True, 'sci': False}
# {'authors': 'Wei Cai, Fuli Feng, Qifan Wang, Tian Yang, Zhenguang Liu, Congfu Xu', 'title': 'A Causal View for Item-level Effect of Recommendation on User Preference', 'year': '2023', 'abbr': 'wsdm', 'type': 'conference', 'ei': True, 'sci': True}
# {'authors': 'Xiaoyu You, Chi Li, Daizong Ding, Mi Zhang, Fuli Feng, Xudong Pan, Min Yang', 'title': 'Anti-FakeU: Defending Shilling Attacks on Graph Neural Network based Recommender Model', 'year': '2023', 'abbr': 'www', 'type': 'conference', 'ei': True, 'sci': True}
# {'authors': 'Fengbin Zhu, Moxin Li, Junbin Xiao, Fuli Feng, Chao Wang, Tat-Seng Chua', 'title': 'SoarGraph: Numerical Reasoning over Financial Table-Text Data via Semantic-Oriented Hierarchical Graphs', 'year': '2023', 'abbr': 'www', 'type': 'conference', 'ei': True, 'sci': True}
# {'authors': 'Xiaoyu You, Beina Sheng, Daizong Ding, Mi Zhang, Xudong Pan, Min Yang, Fuli Feng', 'title': 'MaSS: Model-agnostic, Semantic and Stealthy Data Poisoning Attack on Knowledge Graph Embedding', 'year': '2023', 'abbr': 'www', 'type': 'conference', 'ei': True, 'sci': True}
# {'authors': 'Jinda Lu, Shuo Wang, Xinyu Zhang, Yanbin Hao, Xiangnan He', 'title': 'Semantic-based Selection, Synthesis, and Supervision for Few-shot Learning', 'year': '2023', 'abbr': 'mm', 'type': 'conference', 'ei': False, 'sci': False}
# {'authors': 'Zhenhua Tang, Zhaofan Qiu, Yanbin Hao, Richang Hong, Ting Yao', 'title': '3D Human Pose Estimation with Spatio-Temporal Criss-Cross Attention', 'year': '2023', 'abbr': 'cvpr', 'type': 'conference', 'ei': None, 'sci': True}

# %%
# add full name and level
import json
conf_ref = {}
jour_ref = {}
with open('conf_abbr2ref.json', 'r') as f:
    conf_ref = json.load(f)
with open('jour_abbr2ref.json', 'r') as f:
    jour_ref = json.load(f)

for p_info in paper_infos:
    abbr = p_info['abbr']
    p_type = p_info['type']
    
    if p_type == 'journal':
        level = jour_ref[abbr]['level']
        full_name = jour_ref[abbr]['full_name']
        level_save = '中科院{}区'.format(level)
    elif p_type == 'conference':
        level = conf_ref[abbr]['level']
        full_name = conf_ref[abbr]['full_name']
        level_save = '无' if level == 'No' else 'CCF {}类'.format(level)
    p_info.update({'level': level_save, 'full_name': full_name})

# %%
# save as pd
pd_data = {
    '序号': [],
    '作者': [],
    '文章名称': [],
    '期刊/会议名称': [],
    '类别': [],
    '是否SCI/EI': [],
    '年份': []
}
for i, p_info in enumerate(paper_infos):
    pd_data['序号'].append(i+1)
    pd_data['作者'].append(p_info['authors'])
    pd_data['文章名称'].append(p_info['title'])
    pd_data['期刊/会议名称'].append(p_info['full_name'])
    pd_data['类别'].append(p_info['level'])
    sci_ei = []
    if p_info['sci']:
        sci_ei.append('SCI')
    if p_info['ei']:
        sci_ei.append('EI')     
    pd_data['是否SCI/EI'].append('' if len(sci_ei) == 0 else ','.join(sci_ei))
    pd_data['年份'].append(p_info['year'])

for key in pd_data:
    print('{} : {}'.format(key, len(pd_data[key])))
df = pd.DataFrame(pd_data)
df.to_excel('out.xlsx', sheet_name='2023', index=False)
# Out:
# 序号 : 74
# 作者 : 74
# 文章名称 : 74
# 期刊/会议名称 : 74
# 类别 : 74
# 是否SCI/EI : 74
# 年份 : 74

# %%
for paper in journal_paper_list:
    print(paper['class'])
    aus =  get_authors(paper)
    print(aus)
    title = get_paper_title(paper)
    print(title)
    year = get_year(paper)
    print(year)
    abbr = get_journal_conf_dblp_abbr(paper)
    print(abbr)
# Out:
# ['entry', 'article', 'toc']
# Yuan Gao, Xiang Wang, Xiangnan He, Huamin Feng, Yong-Dong Zhang
# Rumor detection with self-supervised learning on texts and social graph
# 2023
# fcsc
# ['entry', 'article', 'toc']
# Xiang Wang, Yingxin Wu, An Zhang, Fuli Feng, Xiangnan He, Tat-Seng Chua
# Reinforced Causal Explainer for Graph Neural Networks
# 2023
# pami
# ['entry', 'article', 'toc']
# Kang Liu, Feng Xue, Xiangnan He, Dan Guo, Richang Hong
# Joint Multi-Grained Popularity-Aware Graph Convolution Collaborative Filtering for Recommendation
# 2023
# tcss
# ['entry', 'article', 'toc']
# Jintang Li, Tao Xie, Liang Chen, Fenfang Xie, Xiangnan He, Zibin Zheng
# Adversarial Attack on Large Scale Graph
# 2023
# tkde
# ['entry', 'article', 'toc']
# Fuli Feng, Xiangnan He, Hanwang Zhang, Tat-Seng Chua
# Cross-GCN: Enhancing Graph Convolutional Network with $k$k-Order Feature Interactions
# 2023
# tkde
# ['entry', 'article', 'toc']
# Yu Zheng, Chen Gao, Xiangnan He, Depeng Jin, Yong Li
# Incorporating Price into Recommendation With Graph Convolutional Networks
# 2023
# tkde
# ['entry', 'article', 'toc']
# Jianxin Chang, Chen Gao, Xiangnan He, Depeng Jin, Yong Li
# Bundle Recommendation and Generation With Graph Neural Networks
# 2023
# tkde
# ['entry', 'article', 'toc']
# Lei Chen, Fajie Yuan, Jiaxi Yang, Xiangnan He, Chengming Li, Min Yang
# User-Specific Adaptive Fine-Tuning for Cross-Domain Recommendations
# 2023
# tkde
# ['entry', 'article', 'toc']
# Weijian Chen, Fuli Feng, Qifan Wang, Xiangnan He, Chonggang Song, Guohui Ling, Yongdong Zhang
# CatGCN: Graph Convolutional Networks With Categorical Node Features
# 2023
# tkde
# ['entry', 'article', 'toc']
# Le Wu, Xiangnan He, Xiang Wang, Kun Zhang, Meng Wang
# A Survey on Accuracy-Oriented Neural Recommendation: From Collaborative Filtering to Information-Rich Recommendation
# 2023
# tkde
# ['entry', 'article', 'toc']
# Jiajia Chen, Xin Xin, Xianfeng Liang, Xiangnan He, Jun Liu
# GDSRec: Graph-Based Decentralized Collaborative Filtering for Social Recommendation
# 2023
# tkde
# ['entry', 'article', 'toc']
# Zihao Zhao, Jiawei Chen, Sheng Zhou, Xiangnan He, Xuezhi Cao, Fuzheng Zhang, Wei Wu
# Popularity Bias is not Always Evil: Disentangling Benign and Harmful Bias for Recommendation
# 2023
# tkde
# ['entry', 'article', 'toc']
# Yuyue Zhao, Xiang Wang, Jiawei Chen, Yashen Wang, Wei Tang, Xiangnan He, Haiyong Xie
# Time-aware Path Reasoning on Knowledge Graph for Recommendation
# 2023
# tois
# ['entry', 'article', 'toc']
# Xiangnan He, Yang Zhang, Fuli Feng, Chonggang Song, Lingling Yi, Guohui Ling, Yongdong Zhang
# Addressing Confounding Feature Issue for Causal Recommendation
# 2023
# tois
# ['entry', 'article', 'toc']
# Jiawei Chen, Hande Dong, Xiang Wang, Fuli Feng, Meng Wang, Xiangnan He
# Bias and Debias in Recommender System: A Survey and Future Directions
# 2023
# tois
# ['entry', 'article', 'toc']
# Honglei Zhang, Fangyuan Luo, Jun Wu, Xiangnan He, Yidong Li
# LightFR: Lightweight Federated Recommendation with Privacy-preserving Matrix Factorization
# 2023
# tois
# ['entry', 'article', 'toc']
# Shuo Wang, Huixia Ben, Yanbin Hao, Xiangnan He, Meng Wang
# Boosting Hyperspectral Image Classification with Dual Hierarchical Learning
# 2023
# tomccap
# ['entry', 'article', 'toc']
# Bin Wu, Xiangnan He, Le Wu, Xue Zhang, Yangdong Ye
# Graph-Augmented Co-Attention Model for Socio-Sequential Recommendation
# 2023
# tsmc
# ['entry', 'article', 'toc']
# Yinwei Wei, Xiang Wang, Liqiang Nie, Shaoyu Li, Dingxian Wang, Tat-Seng Chua
# Causal Inference for Knowledge Graph Based Recommendation
# 2023
# tkde
# ['entry', 'article', 'toc']
# Zhulin Tao, Xiaohao Liu, Yewei Xia, Xiang Wang, Lifang Yang, Xianglin Huang, Tat-Seng Chua
# Self-Supervised Learning for Multimedia Recommendation
# 2023
# tmm
# ['entry', 'article', 'toc']
# Hongyu Lu, Weizhi Ma, Yifan Wang, Min Zhang, Xiang Wang, Yiqun Liu, Tat-Seng Chua, Shaoping Ma
# User Perception of Recommendation Explanation: Are Your Explanations What Users Need?
# 2023
# tois
# ['entry', 'article', 'toc']
# Xin-Yu Lin, Yiyan Xu, Wenjie Wang, Yang Zhang, Fuli Feng
# Mitigating Spurious Correlations for Self-supervised Recommendation
# 2023
# ijautcomp
# ['entry', 'article', 'toc']
# Shengyu Zhang, Fuli Feng, Kun Kuang, Wenqiao Zhang, Zhou Zhao, Hongxia Yang, Tat-Seng Chua, Fei Wu
# Personalized Latent Structure Learning for Recommendation
# 2023
# pami
# ['entry', 'article', 'toc']
# Jinmeng Wu, Fulin Ge, Hanyu Hong, Yu Shi, Yanbin Hao, Lei Ma
# Question-aware dynamic scene graph of local semantic representation learning for visual question answering
# 2023
# prl

# %%
for paper in conference_paper_list:
    print(paper['class'])
    aus =  get_authors(paper)
    print(aus)
    title = get_paper_title(paper)
    print(title)
    year = get_year(paper)
    print(year)
    abbr = get_journal_conf_dblp_abbr(paper)
    print(abbr)
# Out:
# ['entry', 'inproceedings', 'toc']
# Changyi Xiao, Xiangnan He, Yixin Cao
# Knowledge Graph Embedding by Normalizing Flows
# 2023
# aaai
# ['entry', 'inproceedings', 'toc']
# Xun Deng, Wenjie Wang, Fuli Feng, Hanwang Zhang, Xiangnan He, Yong Liao
# Counterfactual Active Learning for Out-of-Distribution Generalization
# 2023
# acl
# ['entry', 'inproceedings', 'toc']
# Wenjie Wang, Yong Liu, Yang Zhang, Weiwen Liu, Fuli Feng, Xiangnan He, Aixin Sun
# The 1st Workshop on Recommendation with Generative Models
# 2023
# cikm
# ['entry', 'inproceedings', 'toc']
# Zhicai Wang, Yanbin Hao, Tingting Mu, Ouxiang Li, Shuo Wang, Xiangnan He
# Bi-Directional Distribution Alignment for Transductive Zero-Shot Learning
# 2023
# cvpr
# ['entry', 'inproceedings', 'toc']
# Meng Jiang, Yang Zhang, Yuan Gao, Yansong Wang, Fuli Feng, Xiangnan He
# LightMIRM: Light Meta-learned Invariant Risk Minimization for Trustworthy Loan Default Prediction
# 2023
# icde
# ['entry', 'inproceedings', 'toc']
# Yang Liu, Liang Chen, Xiangnan He, Jiaying Peng, Zibin Zheng, Jie Tang
# Modelling High-Order Social Relations for Item Recommendation (Extended Abstract)
# 2023
# icde
# ['entry', 'inproceedings', 'toc']
# Bin Wu, Xiangnan He, Yu Chen, Liqiang Nie, Kai Zheng, Yangdong Ye
# Modeling Product's Visual and Functional Characteristics for Recommender Systems (Extended Abstract)
# 2023
# icde
# ['entry', 'inproceedings', 'toc']
# Hang Pan, Jiawei Chen, Fuli Feng, Wentao Shi, Junkang Wu, Xiangnan He
# Discriminative-Invariant Representation Learning for Unbiased Recommendation
# 2023
# ijcai
# ['entry', 'inproceedings', 'toc']
# Jiarui Yu, Haoran Li, Yanbin Hao, Bin Zhu, Tong Xu, Xiangnan He
# CgT-GAN: CLIP-guided Text GAN for Image Captioning
# 2023
# mm
# ['entry', 'inproceedings', 'toc']
# Changsheng Wang, Jianbai Ye, Wenjie Wang, Chongming Gao, Fuli Feng, Xiangnan He
# RecAD: Towards A Unified Library for Recommender Attack and Defense
# 2023
# recsys
# ['entry', 'inproceedings', 'toc']
# Haoxuan Li, Taojun Hu, Zetong Xiong, Chunyuan Zheng, Fuli Feng, Xiangnan He, Xiao-Hua Zhou
# ADRNet: A Generalized Collaborative Filtering Framework Combining Clinical and Non-Clinical Data for Adverse Drug Reaction Prediction
# 2023
# recsys
# ['entry', 'inproceedings', 'toc']
# Jizhi Zhang, Keqin Bao, Yang Zhang, Wenjie Wang, Fuli Feng, Xiangnan He
# Is ChatGPT Fair for Recommendation? Evaluating Fairness in Large Language Model Recommendation
# 2023
# recsys
# ['entry', 'inproceedings', 'toc']
# Keqin Bao, Jizhi Zhang, Yang Zhang, Wenjie Wang, Fuli Feng, Xiangnan He
# TALLRec: An Effective and Efficient Tuning Framework to Align Large Language Model with Recommendation
# 2023
# recsys
# ['entry', 'inproceedings', 'toc']
# Chongming Gao, Kexin Huang, Jiawei Chen, Yuan Zhang, Biao Li, Peng Jiang, Shiqi Wang, Zhong Zhang, Xiangnan He
# Alleviating Matthew Effect of Offline Reinforcement Learning in Interactive Recommendation
# 2023
# sigir
# ['entry', 'inproceedings', 'toc']
# Zhengyi Yang, Xiangnan He, Jizhi Zhang, Jiancan Wu, Xin Xin, Jiawei Chen, Xiang Wang
# A Generic Learning Framework for Sequential Recommendation with Distribution Shifts
# 2023
# sigir
# ['entry', 'inproceedings', 'toc']
# Wenjie Wang, Yiyan Xu, Fuli Feng, Xinyu Lin, Xiangnan He, Tat-Seng Chua
# Diffusion Recommender Model
# 2023
# sigir
# ['entry', 'inproceedings', 'toc']
# Yang Zhang, Tianhao Shi, Fuli Feng, Wenjie Wang, Dingxian Wang, Xiangnan He, Yongdong Zhang
# Reformulating CTR Prediction: Learning Invariant Feature Interactions for Recommendation
# 2023
# sigir
# ['entry', 'inproceedings', 'toc']
# Wenjie Wang, Yang Zhang, Haoxuan Li, Peng Wu, Fuli Feng, Xiangnan He
# Causal Recommendation: Progresses and Future Directions
# 2023
# sigir
# ['entry', 'inproceedings', 'toc']
# Yuan Gao, Xiang Wang, Xiangnan He, Zhenguang Liu, Huamin Feng, Yongdong Zhang
# Alleviating Structural Distribution Shift in Graph Anomaly Detection
# 2023
# wsdm
# ['entry', 'inproceedings', 'toc']
# Junfeng Fang, Xiang Wang, An Zhang, Zemin Liu, Xiangnan He, Tat-Seng Chua
# Cooperative Explanations of Graph Neural Networks
# 2023
# wsdm
# ['entry', 'inproceedings', 'toc']
# Gang Chen, Jiawei Chen, Fuli Feng, Sheng Zhou, Xiangnan He
# Unbiased Knowledge Distillation for Recommendation
# 2023
# wsdm
# ['entry', 'inproceedings', 'toc']
# Jiancan Wu, Yi Yang, Yuchun Qian, Yongduo Sui, Xiang Wang, Xiangnan He
# GIF: A General Graph Unlearning Strategy via Influence Function
# 2023
# www
# ['entry', 'inproceedings', 'toc']
# Wentao Shi, Jiawei Chen, Fuli Feng, Jizhi Zhang, Junkang Wu, Chongming Gao, Xiangnan He
# On the Theories Behind Hard Negative Sampling for Recommendation
# 2023
# www
# ['entry', 'inproceedings', 'toc']
# Jiawei Chen, Junkang Wu, Jiancan Wu, Xuezhi Cao, Sheng Zhou, Xiangnan He
# Adap-τ : Adaptively Modulating Embedding Magnitude for Recommendation
# 2023
# www
# ['entry', 'inproceedings', 'toc']
# Yuan Gao, Xiang Wang, Xiangnan He, Zhenguang Liu, Huamin Feng, Yongdong Zhang
# Addressing Heterophily in Graph Anomaly Detection: A Perspective of Graph Spectrum
# 2023
# www
# ['entry', 'inproceedings', 'toc']
# An Zhang, Fangfu Liu, Wenchang Ma, Zhibo Cai, Xiang Wang, Tat-Seng Chua
# Boosting Causal Discovery via Adaptive Sample Reweighting
# 2023
# iclr
# ['entry', 'inproceedings', 'toc']
# Jiahao Liu, Jun Zeng, Xiang Wang, Zhenkai Liang
# Learning Graph-based Code Representations for Source-level Functional Similarity Detection
# 2023
# icse
# ['entry', 'inproceedings', 'toc']
# Fangfu Liu, Wenchang Ma, An Zhang, Xiang Wang, Yueqi Duan, Tat-Seng Chua
# Discovering Dynamic Causal Space for DAG Structure Learning
# 2023
# kdd
# ['entry', 'inproceedings', 'toc']
# Yunshan Ma, Chenchen Ye, Zijian Wu, Xiang Wang, Yixin Cao, Tat-Seng Chua
# Context-aware Event Forecasting via Graph Disentanglement
# 2023
# kdd
# ['entry', 'inproceedings', 'toc']
# Yicong Li, Xun Yang, An Zhang, Chun Feng, Xiang Wang, Tat-Seng Chua
# Redundancy-aware Transformer for Video Question Answering
# 2023
# mm
# ['entry', 'inproceedings', 'toc']
# Yinwei Wei, Xiaohao Liu, Yunshan Ma, Xiang Wang, Liqiang Nie, Tat-Seng Chua
# Strategy-aware Bundle Recommender System
# 2023
# sigir
# ['entry', 'inproceedings', 'toc']
# Yinwei Wei, Wenqi Liu, Fan Liu, Xiang Wang, Liqiang Nie, Tat-Seng Chua
# LightGT: A Light Graph Transformer for Multimedia Recommendation
# 2023
# sigir
# ['entry', 'inproceedings', 'toc']
# An Zhang, Jingnan Zheng, Xiang Wang, Yancheng Yuan, Tat-Seng Chua
# Invariant Collaborative Filtering to Popularity Distribution Shift
# 2023
# www
# ['entry', 'inproceedings', 'toc']
# Daizong Ding, Mi Zhang, Fuli Feng, Yuanmin Huang, Erling Jiang, Min Yang
# Black-Box Adversarial Attack on Time Series Classification
# 2023
# aaai
# ['entry', 'inproceedings', 'toc']
# Shengyu Zhang, Xusheng Feng, Wenyan Fan, Wenjing Fang, Fuli Feng, Wei Ji, Shuo Li, Li Wang, Shanshan Zhao, Zhou Zhao, Tat-Seng Chua, Fei Wu
# Video-Audio Domain Generalization via Confounder Disentanglement
# 2023
# aaai
# ['entry', 'inproceedings', 'toc']
# Moxin Li, Wenjie Wang, Fuli Feng, Hanwang Zhang, Qifan Wang, Tat-Seng Chua
# Hypothetical Training for Robust Machine Reading Comprehension of Tabular Context
# 2023
# acl
# ['entry', 'inproceedings', 'toc']
# Qifan Wang, Jingang Wang, Xiaojun Quan, Fuli Feng, Zenglin Xu, Shaoliang Nie, Sinong Wang, Madian Khabsa, Hamed Firooz, Dongfang Liu
# MUSTIE: Multimodal Structural Transformer for Web Information Extraction
# 2023
# acl
# ['entry', 'inproceedings', 'toc']
# Li Yang, Qifan Wang, Jingang Wang, Xiaojun Quan, Fuli Feng, Yu Chen, Madian Khabsa, Sinong Wang, Zenglin Xu, Dongfang Liu
# MixPAVE: Mix-Prompt Tuning for Few-shot Product Attribute Value Extraction
# 2023
# acl
# ['entry', 'inproceedings', 'toc']
# Yang Zhang, Yimeng Bai, Jianxin Chang, Xiaoxue Zang, Song Lu, Jing Lu, Fuli Feng, Yanan Niu, Yang Song
# Leveraging Watch-time Feedback for Short-Video Recommendations: A Causal Labeling Framework
# 2023
# cikm
# ['entry', 'inproceedings', 'toc']
# Yang Liu, Xiang Ao, Fuli Feng, Yunshan Ma, Kuan Li, Tat-Seng Chua, Qing He
# FLOOD: A Flexible Invariant Learning Framework for Out-of-Distribution Generalization on Graphs
# 2023
# kdd
# ['entry', 'inproceedings', 'toc']
# Shengyu Zhang, Yunze Tong, Kun Kuang, Fuli Feng, Jiezhong Qiu, Jin Yu, Zhou Zhao, Hongxia Yang, Zhongfei Zhang, Fei Wu
# Stable Prediction on Graphs with Agnostic Distribution Shifts
# 2023
# kddcd
# ['entry', 'inproceedings', 'toc']
# Wenjie Wang, Xinyu Lin, Liuhui Wang, Fuli Feng, Yinwei Wei, Tat-Seng Chua
# Equivariant Learning for Out-of-Distribution Cold-start Recommendation
# 2023
# mm
# ['entry', 'inproceedings', 'toc']
# Wei Ji, Renjie Liang, Lizi Liao, Hao Fei, Fuli Feng
# Partial Annotation-based Video Moment Retrieval via Iterative Learning
# 2023
# mm
# ['entry', 'inproceedings', 'toc']
# Yulong Huang, Yang Zhang, Qifan Wang, Chenxu Wang, Fuli Feng
# Prediction then Correction: An Abductive Prediction Correction Method for Sequential Recommendation
# 2023
# sigir
# ['entry', 'inproceedings', 'toc']
# Wei Cai, Fuli Feng, Qifan Wang, Tian Yang, Zhenguang Liu, Congfu Xu
# A Causal View for Item-level Effect of Recommendation on User Preference
# 2023
# wsdm
# ['entry', 'inproceedings', 'toc']
# Xiaoyu You, Chi Li, Daizong Ding, Mi Zhang, Fuli Feng, Xudong Pan, Min Yang
# Anti-FakeU: Defending Shilling Attacks on Graph Neural Network based Recommender Model
# 2023
# www
# ['entry', 'inproceedings', 'toc']
# Fengbin Zhu, Moxin Li, Junbin Xiao, Fuli Feng, Chao Wang, Tat-Seng Chua
# SoarGraph: Numerical Reasoning over Financial Table-Text Data via Semantic-Oriented Hierarchical Graphs
# 2023
# www
# ['entry', 'inproceedings', 'toc']
# Xiaoyu You, Beina Sheng, Daizong Ding, Mi Zhang, Xudong Pan, Min Yang, Fuli Feng
# MaSS: Model-agnostic, Semantic and Stealthy Data Poisoning Attack on Knowledge Graph Embedding
# 2023
# www
# ['entry', 'inproceedings', 'toc']
# Jinda Lu, Shuo Wang, Xinyu Zhang, Yanbin Hao, Xiangnan He
# Semantic-based Selection, Synthesis, and Supervision for Few-shot Learning
# 2023
# mm
# ['entry', 'inproceedings', 'toc']
# Zhenhua Tang, Zhaofan Qiu, Yanbin Hao, Richang Hong, Ting Yao
# 3D Human Pose Estimation with Spatio-Temporal Criss-Cross Attention
# 2023
# cvpr
